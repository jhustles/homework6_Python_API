# %% [markdown]
# # Homework 6: WeatherPy
#
# ### Johneson Giang
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# %matplotlib notebook

import matplotlib.pyplot as plt
import json
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import os
import csv

# Import API key
from wapik_blooms import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities - GIVEN
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %%
#print(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Setup URL and Query URL

url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = url + "appid=" + api_key + "&q="


# Set up counters and lists
# this step came later after I ran a few test responses to see the format of the data

record_counter = 0
set_counter = 1

city_name = []
cod = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Account for skips - added this towards the end
skip_counter = 0
skip_list = []

print(query_url)

print("Beginning Data Retrieval")
print('-'*30)

# set up loop
for city in cities:

    response_data = requests.get(query_url + city).json()

    try:
        city_name.append(response_data['name'])
        cod.append(response_data['cod'])
        cloudiness.append(response_data['clouds']['all'])
        country.append(response_data['sys']['country'])
        date.append(response_data['dt'])
        humidity.append(response_data['main']['humidity'])
        lat.append(response_data['coord']['lat'])
        lng.append(response_data['coord']['lon'])
        max_temp.append(response_data['main']['temp_max'])
        wind_speed.append(response_data['wind']['speed'])
        print("Processing Record " + str(record_counter) + " of Set " + str(set_counter) + " | " + str.title(city))

    except (KeyError, NameError, TypeError, AttributeError):      
        print("Processing Record " + str(record_counter) + " of Set " + str(set_counter) + " | " + str.title(city))
        print(f"The requested city of: {str.title(city)} was not found. Skipping...")
        #cod.append(response.status_code) - will remove this because was causing issues.
        skip_counter += 1
        skip_list.append(city)
            

    record_counter += 1
    if record_counter == 51:
        set_counter += 1
        record_counter = 1
    
print('-'*30)
print('Data Retrieval Complete')
print('-'*30)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=6e01409e508e9c452a34604334dd7a3c&q=
# Beginning Data Retrieval
# ------------------------------
# Processing Record 0 of Set 1 | Balimo
# The requested city of: Balimo was not found. Skipping...
# Processing Record 1 of Set 1 | Guerrero Negro
# Processing Record 2 of Set 1 | Albany
# Processing Record 3 of Set 1 | Vaini
# Processing Record 4 of Set 1 | Kununurra
# Processing Record 5 of Set 1 | Castro
# Processing Record 6 of Set 1 | Ondorhaan
# The requested city of: Ondorhaan was not found. Skipping...
# Processing Record 7 of Set 1 | Ushuaia
# Processing Record 8 of Set 1 | Qaanaaq
# Processing Record 9 of Set 1 | Harlingen
# Processing Record 10 of Set 1 | Bengkulu
# The requested city of: Bengkulu was not found. Skipping...
# Processing Record 11 of Set 1 | Nikolskoye
# Processing Record 12 of Set 1 | Musoma
# Processing Record 13 of Set 1 | Srednekolymsk
# Processing Record 14 of Set 1 | Hobart
# Processing Record 15 of Set 1 | Khandyga
# Processing Record 16 of Set 1 | Hilo
# Processing Record 17 of Set 1 | Talnakh
# Processing Record 18 of Set 1 | Hermanus
# Processing Record 19 of Set 1 | Lasa
# Processing Record 20 of Set 1 | Qui Nhon
# The requested city of: Qui Nhon was not found. Skipping...
# Processing Record 21 of Set 1 | Aberdeen
# Processing Record 22 of Set 1 | New Norfolk
# Processing Record 23 of Set 1 | Rikitea
# Processing Record 24 of Set 1 | Kieta
# Processing Record 25 of Set 1 | Show Low
# Processing Record 26 of Set 1 | Butaritari
# Processing Record 27 of Set 1 | Bluff
# Processing Record 28 of Set 1 | Rawson
# Processing Record 29 of Set 1 | Busselton
# Processing Record 30 of Set 1 | Cape Town
# Processing Record 31 of Set 1 | Cherskiy
# Processing Record 32 of Set 1 | Lamu
# Processing Record 33 of Set 1 | Sentyabrskiy
# The requested city of: Sentyabrskiy was not found. Skipping...
# Processing Record 34 of Set 1 | Norman Wells
# Processing Record 35 of Set 1 | Ribeira Grande
# Processing Record 36 of Set 1 | Yellowknife
# Processing Record 37 of Set 1 | Isangel
# Processing Record 38 of Set 1 | Kapaa
# Processing Record 39 of Set 1 | Belushya Guba
# The requested city of: Belushya Guba was not found. Skipping...
# Processing Record 40 of Set 1 | Airai
# Processing Record 41 of Set 1 | Sioux Lookout
# Processing Record 42 of Set 1 | Bad Frankenhausen
# Processing Record 43 of Set 1 | Umaria
# Processing Record 44 of Set 1 | East London
# Processing Record 45 of Set 1 | Luderitz
# Processing Record 46 of Set 1 | Mar Del Plata
# Processing Record 47 of Set 1 | Mataura
# Processing Record 48 of Set 1 | Avarua
# Processing Record 49 of Set 1 | Arona
# Processing Record 50 of Set 1 | Ancud
# Processing Record 1 of Set 2 | Nanortalik
# Processing Record 2 of Set 2 | Ijaki
# The requested city of: Ijaki was not found. Skipping...
# Processing Record 3 of Set 2 | Naziya
# Processing Record 4 of Set 2 | Bethel
# Processing Record 5 of Set 2 | Port Alfred
# Processing Record 6 of Set 2 | Amderma
# The requested city of: Amderma was not found. Skipping...
# Processing Record 7 of Set 2 | Severo-Kurilsk
# Processing Record 8 of Set 2 | Padang
# Processing Record 9 of Set 2 | Fairbanks
# Processing Record 10 of Set 2 | Lerwick
# Processing Record 11 of Set 2 | Tuktoyaktuk
# Processing Record 12 of Set 2 | Wilmington
# Processing Record 13 of Set 2 | Port Elizabeth
# Processing Record 14 of Set 2 | Punta Arenas
# Processing Record 15 of Set 2 | Ahipara
# Processing Record 16 of Set 2 | Sevierville
# Processing Record 17 of Set 2 | Bo
# The requested city of: Bo was not found. Skipping...
# Processing Record 18 of Set 2 | Broken Hill
# Processing Record 19 of Set 2 | Petropavlovsk-Kamchatskiy
# Processing Record 20 of Set 2 | Ginir
# Processing Record 21 of Set 2 | Ponta Do Sol
# Processing Record 22 of Set 2 | Faanui
# Processing Record 23 of Set 2 | Asifabad
# Processing Record 24 of Set 2 | Ouesso
# Processing Record 25 of Set 2 | Waipawa
# Processing Record 26 of Set 2 | Tasiilaq
# Processing Record 27 of Set 2 | Masvingo
# Processing Record 28 of Set 2 | Carnarvon
# Processing Record 29 of Set 2 | Luganville
# Processing Record 30 of Set 2 | Medea
# Processing Record 31 of Set 2 | Barrow
# Processing Record 32 of Set 2 | Bambous Virieux
# Processing Record 33 of Set 2 | Naryan-Mar
# Processing Record 34 of Set 2 | Mahaicony
# The requested city of: Mahaicony was not found. Skipping...
# Processing Record 35 of Set 2 | Sitka
# Processing Record 36 of Set 2 | Mount Isa
# Processing Record 37 of Set 2 | Shieli
# Processing Record 38 of Set 2 | Sao Felix Do Xingu
# Processing Record 39 of Set 2 | Mrirt
# The requested city of: Mrirt was not found. Skipping...
# Processing Record 40 of Set 2 | Chuy
# Processing Record 41 of Set 2 | Saint Anthony
# Processing Record 42 of Set 2 | Hasanabad
# Processing Record 43 of Set 2 | Tabivere
# Processing Record 44 of Set 2 | Dolbeau
# The requested city of: Dolbeau was not found. Skipping...
# Processing Record 45 of Set 2 | Bredasdorp
# Processing Record 46 of Set 2 | Thompson
# Processing Record 47 of Set 2 | Jieshi
# Processing Record 48 of Set 2 | Sao Joao Da Barra
# Processing Record 49 of Set 2 | Fomboni
# Processing Record 50 of Set 2 | Inderborskiy
# The requested city of: Inderborskiy was not found. Skipping...
# Processing Record 1 of Set 3 | Yarmouth
# Processing Record 2 of Set 3 | Saldanha
# Processing Record 3 of Set 3 | Kaitangata
# Processing Record 4 of Set 3 | Necochea
# Processing Record 5 of Set 3 | Popondetta
# Processing Record 6 of Set 3 | Teshie
# Processing Record 7 of Set 3 | Illoqqortoormiut
# The requested city of: Illoqqortoormiut was not found. Skipping...
# Processing Record 8 of Set 3 | Fortuna
# Processing Record 9 of Set 3 | Lhokseumawe
# Processing Record 10 of Set 3 | Longyearbyen
# Processing Record 11 of Set 3 | Samusu
# The requested city of: Samusu was not found. Skipping...
# Processing Record 12 of Set 3 | Manta
# Processing Record 13 of Set 3 | Attawapiskat
# The requested city of: Attawapiskat was not found. Skipping...
# Processing Record 14 of Set 3 | Richards Bay
# Processing Record 15 of Set 3 | Grenada
# Processing Record 16 of Set 3 | Georgetown
# Processing Record 17 of Set 3 | Carmelo
# Processing Record 18 of Set 3 | Cidreira
# Processing Record 19 of Set 3 | Barentsburg
# The requested city of: Barentsburg was not found. Skipping...
# Processing Record 20 of Set 3 | Itacoatiara
# Processing Record 21 of Set 3 | Torbay
# Processing Record 22 of Set 3 | Toliary
# The requested city of: Toliary was not found. Skipping...
# Processing Record 23 of Set 3 | Mackenzie
# Processing Record 24 of Set 3 | Jucurutu
# Processing Record 25 of Set 3 | Puerto Ayora
# Processing Record 26 of Set 3 | Urambo
# Processing Record 27 of Set 3 | Taolanaro
# The requested city of: Taolanaro was not found. Skipping...
# Processing Record 28 of Set 3 | Margate
# Processing Record 29 of Set 3 | Baijiantan
# Processing Record 30 of Set 3 | Saleaula
# The requested city of: Saleaula was not found. Skipping...
# Processing Record 31 of Set 3 | Lebu
# Processing Record 32 of Set 3 | Bantou
# Processing Record 33 of Set 3 | Olafsvik
# The requested city of: Olafsvik was not found. Skipping...
# Processing Record 34 of Set 3 | Puerto Del Rosario
# Processing Record 35 of Set 3 | Camacha
# Processing Record 36 of Set 3 | Fort Nelson
# Processing Record 37 of Set 3 | Loiza
# Processing Record 38 of Set 3 | Potsdam
# Processing Record 39 of Set 3 | Leshukonskoye
# Processing Record 40 of Set 3 | Tuatapere
# Processing Record 41 of Set 3 | Prince Rupert
# Processing Record 42 of Set 3 | Changli
# Processing Record 43 of Set 3 | Namatanai
# Processing Record 44 of Set 3 | Bilma
# Processing Record 45 of Set 3 | Karratha
# Processing Record 46 of Set 3 | Narsaq
# Processing Record 47 of Set 3 | Lewisporte
# Processing Record 48 of Set 3 | Dashitou
# Processing Record 49 of Set 3 | Temaraia
# The requested city of: Temaraia was not found. Skipping...
# Processing Record 50 of Set 3 | Esperance
# Processing Record 1 of Set 4 | Victoria
# Processing Record 2 of Set 4 | Wajid
# Processing Record 3 of Set 4 | Yar-Sale
# Processing Record 4 of Set 4 | Iqaluit
# Processing Record 5 of Set 4 | Jati
# Processing Record 6 of Set 4 | Ruidoso
# Processing Record 7 of Set 4 | Porto Nacional
# Processing Record 8 of Set 4 | Dikson
# Processing Record 9 of Set 4 | Jamestown
# Processing Record 10 of Set 4 | Praya
# Processing Record 11 of Set 4 | Hammerfest
# Processing Record 12 of Set 4 | Belmonte
# Processing Record 13 of Set 4 | Liuhe
# Processing Record 14 of Set 4 | Umzimvubu
# The requested city of: Umzimvubu was not found. Skipping...
# Processing Record 15 of Set 4 | Lengshuijiang
# Processing Record 16 of Set 4 | Aklavik
# Processing Record 17 of Set 4 | Lagoa
# Processing Record 18 of Set 4 | Provideniya
# Processing Record 19 of Set 4 | Chubbuck
# Processing Record 20 of Set 4 | Glyadyanskoye
# Processing Record 21 of Set 4 | Novaya Zaimka
# Processing Record 22 of Set 4 | Sri Aman
# Processing Record 23 of Set 4 | San Patricio
# Processing Record 24 of Set 4 | Chokurdakh
# Processing Record 25 of Set 4 | Arlit
# Processing Record 26 of Set 4 | Nsanje
# Processing Record 27 of Set 4 | Cabo San Lucas
# Processing Record 28 of Set 4 | Porto Walter
# Processing Record 29 of Set 4 | Ilulissat
# Processing Record 30 of Set 4 | Tilichiki
# Processing Record 31 of Set 4 | Tsihombe
# The requested city of: Tsihombe was not found. Skipping...
# Processing Record 32 of Set 4 | Deputatskiy
# Processing Record 33 of Set 4 | Kodiak
# Processing Record 34 of Set 4 | Copala
# Processing Record 35 of Set 4 | Shakawe
# Processing Record 36 of Set 4 | Belaya Gora
# Processing Record 37 of Set 4 | Nguiu
# The requested city of: Nguiu was not found. Skipping...
# Processing Record 38 of Set 4 | Saint-Philippe
# Processing Record 39 of Set 4 | Mahebourg
# Processing Record 40 of Set 4 | Manokwari
# Processing Record 41 of Set 4 | Goderich
# Processing Record 42 of Set 4 | Vestmannaeyjar
# Processing Record 43 of Set 4 | Dingle
# Processing Record 44 of Set 4 | Alofi
# Processing Record 45 of Set 4 | Kavieng
# Processing Record 46 of Set 4 | Mitsamiouli
# Processing Record 47 of Set 4 | Denpasar
# Processing Record 48 of Set 4 | Arraial Do Cabo
# Processing Record 49 of Set 4 | Oxkutzcab
# Processing Record 50 of Set 4 | Hwange
# Processing Record 1 of Set 5 | Gizo
# Processing Record 2 of Set 5 | Fevralsk
# The requested city of: Fevralsk was not found. Skipping...
# Processing Record 3 of Set 5 | Talah
# The requested city of: Talah was not found. Skipping...
# Processing Record 4 of Set 5 | Hofn
# Processing Record 5 of Set 5 | Kalanguy
# Processing Record 6 of Set 5 | Shawville
# Processing Record 7 of Set 5 | Le Port
# Processing Record 8 of Set 5 | Sur
# Processing Record 9 of Set 5 | Maridi
# The requested city of: Maridi was not found. Skipping...
# Processing Record 10 of Set 5 | Muros
# Processing Record 11 of Set 5 | Atuona
# Processing Record 12 of Set 5 | Gat
# Processing Record 13 of Set 5 | Imeni Poliny Osipenko
# Processing Record 14 of Set 5 | Verkhnechusovskiye Gorodki
# Processing Record 15 of Set 5 | Paraiso
# Processing Record 16 of Set 5 | Buraydah
# Processing Record 17 of Set 5 | Great Falls
# Processing Record 18 of Set 5 | Sola
# Processing Record 19 of Set 5 | Tahoua
# Processing Record 20 of Set 5 | Moose Factory
# Processing Record 21 of Set 5 | Lompoc
# Processing Record 22 of Set 5 | Serov
# Processing Record 23 of Set 5 | Omboue
# Processing Record 24 of Set 5 | Saint Leonard
# Processing Record 25 of Set 5 | Saskylakh
# Processing Record 26 of Set 5 | Impfondo
# Processing Record 27 of Set 5 | Changqing
# Processing Record 28 of Set 5 | Raudeberg
# Processing Record 29 of Set 5 | Mount Gambier
# Processing Record 30 of Set 5 | Grand River South East
# The requested city of: Grand River South East was not found. Skipping...
# Processing Record 31 of Set 5 | Chitral
# Processing Record 32 of Set 5 | Marawi
# Processing Record 33 of Set 5 | Bijie
# Processing Record 34 of Set 5 | Chingirlau
# Processing Record 35 of Set 5 | Kavaratti
# Processing Record 36 of Set 5 | Umm Durman
# The requested city of: Umm Durman was not found. Skipping...
# Processing Record 37 of Set 5 | Yomitan
# The requested city of: Yomitan was not found. Skipping...
# Processing Record 38 of Set 5 | Korla
# The requested city of: Korla was not found. Skipping...
# Processing Record 39 of Set 5 | Pisco
# Processing Record 40 of Set 5 | Tiksi
# Processing Record 41 of Set 5 | Sinnamary
# Processing Record 42 of Set 5 | Lamar
# Processing Record 43 of Set 5 | Dunedin
# Processing Record 44 of Set 5 | Yeppoon
# Processing Record 45 of Set 5 | Lebyazhye
# Processing Record 46 of Set 5 | Vostok
# Processing Record 47 of Set 5 | Matagami
# Processing Record 48 of Set 5 | Khatanga
# Processing Record 49 of Set 5 | Yuzhnyy
# Processing Record 50 of Set 5 | Sandviken
# Processing Record 1 of Set 6 | La Esperanza
# Processing Record 2 of Set 6 | Puerto Escondido
# Processing Record 3 of Set 6 | Paita
# Processing Record 4 of Set 6 | Mount Pleasant
# Processing Record 5 of Set 6 | Hirara
# Processing Record 6 of Set 6 | Redlands
# Processing Record 7 of Set 6 | Lahad Datu
# Processing Record 8 of Set 6 | Gari
# Processing Record 9 of Set 6 | Pecigrad
# Processing Record 10 of Set 6 | Trincomalee
# Processing Record 11 of Set 6 | Wuwei
# Processing Record 12 of Set 6 | Guajara-Mirim
# The requested city of: Guajara-Mirim was not found. Skipping...
# Processing Record 13 of Set 6 | Maumere
# Processing Record 14 of Set 6 | Kracheh
# The requested city of: Kracheh was not found. Skipping...
# Processing Record 15 of Set 6 | Horta
# Processing Record 16 of Set 6 | Los Llanos De Aridane
# Processing Record 17 of Set 6 | Tukums
# Processing Record 18 of Set 6 | Hithadhoo
# Processing Record 19 of Set 6 | Murgab
# Processing Record 20 of Set 6 | Adjumani
# Processing Record 21 of Set 6 | Zaysan
# Processing Record 22 of Set 6 | Buchanan
# Processing Record 23 of Set 6 | Faya
# Processing Record 24 of Set 6 | La Ronge
# Processing Record 25 of Set 6 | Kangaatsiaq
# Processing Record 26 of Set 6 | Talcahuano
# Processing Record 27 of Set 6 | Ola
# Processing Record 28 of Set 6 | Houma
# Processing Record 29 of Set 6 | Veraval
# Processing Record 30 of Set 6 | Auki
# Processing Record 31 of Set 6 | Nishihara
# Processing Record 32 of Set 6 | Mkushi
# Processing Record 33 of Set 6 | Rorvik
# Processing Record 34 of Set 6 | San Quintin
# Processing Record 35 of Set 6 | Ballina
# Processing Record 36 of Set 6 | Adrar
# Processing Record 37 of Set 6 | Santa Rosa
# Processing Record 38 of Set 6 | Karatau
# Processing Record 39 of Set 6 | Pangnirtung
# Processing Record 40 of Set 6 | Sabla
# Processing Record 41 of Set 6 | Tezu
# Processing Record 42 of Set 6 | Saint-Francois
# Processing Record 43 of Set 6 | Chokwe
# The requested city of: Chokwe was not found. Skipping...
# Processing Record 44 of Set 6 | Inuvik
# Processing Record 45 of Set 6 | Kamenskoye
# The requested city of: Kamenskoye was not found. Skipping...
# Processing Record 46 of Set 6 | Seydi
# Processing Record 47 of Set 6 | High Level
# Processing Record 48 of Set 6 | Bur Gabo
# The requested city of: Bur Gabo was not found. Skipping...
# Processing Record 49 of Set 6 | Ituporanga
# Processing Record 50 of Set 6 | Pogonsili
# The requested city of: Pogonsili was not found. Skipping...
# Processing Record 1 of Set 7 | Ayr
# Processing Record 2 of Set 7 | Carballo
# Processing Record 3 of Set 7 | Lotoshino
# Processing Record 4 of Set 7 | Kungalv
# Processing Record 5 of Set 7 | La Orilla
# Processing Record 6 of Set 7 | Komsomolskiy
# Processing Record 7 of Set 7 | Mayor Pablo Lagerenza
# Processing Record 8 of Set 7 | Ozgon
# The requested city of: Ozgon was not found. Skipping...
# Processing Record 9 of Set 7 | San Juan
# Processing Record 10 of Set 7 | Pauini
# Processing Record 11 of Set 7 | Grindavik
# Processing Record 12 of Set 7 | Monroe
# Processing Record 13 of Set 7 | Buseresere
# Processing Record 14 of Set 7 | Cuamba
# Processing Record 15 of Set 7 | Souillac
# Processing Record 16 of Set 7 | Cabra
# Processing Record 17 of Set 7 | Quelimane
# Processing Record 18 of Set 7 | Zakharovo
# Processing Record 19 of Set 7 | Diffa
# Processing Record 20 of Set 7 | Tanout
# Processing Record 21 of Set 7 | Takoradi
# Processing Record 22 of Set 7 | Villa Carlos Paz
# Processing Record 23 of Set 7 | Halifax
# Processing Record 24 of Set 7 | Arman
# Processing Record 25 of Set 7 | Mys Shmidta
# The requested city of: Mys Shmidta was not found. Skipping...
# Processing Record 26 of Set 7 | Ntungamo
# Processing Record 27 of Set 7 | Lazaro Cardenas
# Processing Record 28 of Set 7 | Tazovskiy
# Processing Record 29 of Set 7 | Kirando
# Processing Record 30 of Set 7 | Yangjiang
# Processing Record 31 of Set 7 | Carutapera
# Processing Record 32 of Set 7 | Barra
# Processing Record 33 of Set 7 | Alugan
# Processing Record 34 of Set 7 | Carlsbad
# Processing Record 35 of Set 7 | Lyaskelya
# Processing Record 36 of Set 7 | Fort Saint John
# The requested city of: Fort Saint John was not found. Skipping...
# Processing Record 37 of Set 7 | Kaduqli
# Processing Record 38 of Set 7 | Katsuura
# Processing Record 39 of Set 7 | Yabelo
# Processing Record 40 of Set 7 | Meulaboh
# Processing Record 41 of Set 7 | Upernavik
# Processing Record 42 of Set 7 | Nabire
# Processing Record 43 of Set 7 | Latehar
# Processing Record 44 of Set 7 | Hamilton
# Processing Record 45 of Set 7 | Tumannyy
# The requested city of: Tumannyy was not found. Skipping...
# Processing Record 46 of Set 7 | Hasaki
# Processing Record 47 of Set 7 | Touros
# Processing Record 48 of Set 7 | Suruc
# Processing Record 49 of Set 7 | Seoul
# Processing Record 50 of Set 7 | Laguna
# Processing Record 1 of Set 8 | Mantua
# Processing Record 2 of Set 8 | Kloulklubed
# Processing Record 3 of Set 8 | Riaba
# The requested city of: Riaba was not found. Skipping...
# Processing Record 4 of Set 8 | Kuusamo
# Processing Record 5 of Set 8 | Salalah
# Processing Record 6 of Set 8 | Hay River
# Processing Record 7 of Set 8 | Ostrovnoy
# Processing Record 8 of Set 8 | Lolua
# The requested city of: Lolua was not found. Skipping...
# Processing Record 9 of Set 8 | Naze
# Processing Record 10 of Set 8 | Ilave
# Processing Record 11 of Set 8 | Uyskoye
# Processing Record 12 of Set 8 | Gumusyaka
# The requested city of: Gumusyaka was not found. Skipping...
# Processing Record 13 of Set 8 | Cabedelo
# Processing Record 14 of Set 8 | Vaitupu
# The requested city of: Vaitupu was not found. Skipping...
# Processing Record 15 of Set 8 | Maragogi
# Processing Record 16 of Set 8 | Pevek
# Processing Record 17 of Set 8 | Camacupa
# Processing Record 18 of Set 8 | Hualmay
# Processing Record 19 of Set 8 | Bireun
# Processing Record 20 of Set 8 | Buin
# Processing Record 21 of Set 8 | San Juan Del Sur
# Processing Record 22 of Set 8 | Rio Gallegos
# Processing Record 23 of Set 8 | Galich
# Processing Record 24 of Set 8 | Crab Hill
# The requested city of: Crab Hill was not found. Skipping...
# Processing Record 25 of Set 8 | Velten
# Processing Record 26 of Set 8 | Ixtapa
# Processing Record 27 of Set 8 | Bathsheba
# Processing Record 28 of Set 8 | Scarborough
# Processing Record 29 of Set 8 | Povoa De Varzim
# Processing Record 30 of Set 8 | Baherden
# Processing Record 31 of Set 8 | Mazagao
# Processing Record 32 of Set 8 | Oksfjord
# Processing Record 33 of Set 8 | Baykit
# Processing Record 34 of Set 8 | Klaksvik
# Processing Record 35 of Set 8 | Samarai
# Processing Record 36 of Set 8 | Flin Flon
# Processing Record 37 of Set 8 | Manzil Tamim
# The requested city of: Manzil Tamim was not found. Skipping...
# Processing Record 38 of Set 8 | Dhrol
# Processing Record 39 of Set 8 | Eyl
# Processing Record 40 of Set 8 | Mandalgovi
# Processing Record 41 of Set 8 | Tucupita
# Processing Record 42 of Set 8 | Nantucket
# Processing Record 43 of Set 8 | Along
# Processing Record 44 of Set 8 | Phan Thiet
# Processing Record 45 of Set 8 | Ternate
# Processing Record 46 of Set 8 | San
# Processing Record 47 of Set 8 | Taranagar
# Processing Record 48 of Set 8 | Bukama
# Processing Record 49 of Set 8 | Sherbakul
# Processing Record 50 of Set 8 | Longhua
# Processing Record 1 of Set 9 | Benguela
# Processing Record 2 of Set 9 | Mehamn
# Processing Record 3 of Set 9 | Yulara
# Processing Record 4 of Set 9 | Mbanza-Ngungu
# Processing Record 5 of Set 9 | Valleyview
# Processing Record 6 of Set 9 | Avera
# Processing Record 7 of Set 9 | Penzance
# Processing Record 8 of Set 9 | Tabas
# Processing Record 9 of Set 9 | Wanaka
# Processing Record 10 of Set 9 | Labuhan
# Processing Record 11 of Set 9 | Shuangyang
# Processing Record 12 of Set 9 | Paamiut
# Processing Record 13 of Set 9 | Tambopata
# The requested city of: Tambopata was not found. Skipping...
# Processing Record 14 of Set 9 | Marystown
# Processing Record 15 of Set 9 | Kjollefjord
# Processing Record 16 of Set 9 | Konza
# Processing Record 17 of Set 9 | North Bend
# Processing Record 18 of Set 9 | Zaterechnyy
# Processing Record 19 of Set 9 | Uaua
# Processing Record 20 of Set 9 | Flinders
# Processing Record 21 of Set 9 | Polewali
# Processing Record 22 of Set 9 | Port Keats
# Processing Record 23 of Set 9 | Sussex
# Processing Record 24 of Set 9 | Toftir
# The requested city of: Toftir was not found. Skipping...
# Processing Record 25 of Set 9 | Kiunga
# Processing Record 26 of Set 9 | Kailua
# Processing Record 27 of Set 9 | Vila Velha
# Processing Record 28 of Set 9 | Morki
# Processing Record 29 of Set 9 | Gimli
# Processing Record 30 of Set 9 | Toyooka
# Processing Record 31 of Set 9 | Narrabri
# Processing Record 32 of Set 9 | Mwinilunga
# Processing Record 33 of Set 9 | Yenagoa
# Processing Record 34 of Set 9 | Noyabrsk
# Processing Record 35 of Set 9 | Moses Lake
# Processing Record 36 of Set 9 | Teguise
# Processing Record 37 of Set 9 | Caravelas
# Processing Record 38 of Set 9 | Olinda
# Processing Record 39 of Set 9 | Portland
# Processing Record 40 of Set 9 | Voh
# Processing Record 41 of Set 9 | Port Hardy
# Processing Record 42 of Set 9 | Mana
# Processing Record 43 of Set 9 | Troitskoye
# Processing Record 44 of Set 9 | Hihifo
# The requested city of: Hihifo was not found. Skipping...
# Processing Record 45 of Set 9 | Jalu
# Processing Record 46 of Set 9 | Ketchikan
# Processing Record 47 of Set 9 | Sao Filipe
# Processing Record 48 of Set 9 | Burnie
# Processing Record 49 of Set 9 | Tshane
# Processing Record 50 of Set 9 | Taksimo
# Processing Record 1 of Set 10 | Ballarat
# Processing Record 2 of Set 10 | Xiongzhou
# Processing Record 3 of Set 10 | Dutse
# Processing Record 4 of Set 10 | Nanhai
# Processing Record 5 of Set 10 | Buarcos
# Processing Record 6 of Set 10 | Aksarka
# Processing Record 7 of Set 10 | Nizhneyansk
# The requested city of: Nizhneyansk was not found. Skipping...
# Processing Record 8 of Set 10 | Goma
# Processing Record 9 of Set 10 | Clyde River
# Processing Record 10 of Set 10 | Salaga
# Processing Record 11 of Set 10 | Vestmanna
# Processing Record 12 of Set 10 | Saint George
# Processing Record 13 of Set 10 | Skalistyy
# The requested city of: Skalistyy was not found. Skipping...
# Processing Record 14 of Set 10 | Mastic Beach
# Processing Record 15 of Set 10 | Teguldet
# Processing Record 16 of Set 10 | Yaan
# Processing Record 17 of Set 10 | Kruisfontein
# Processing Record 18 of Set 10 | Barawe
# The requested city of: Barawe was not found. Skipping...
# Processing Record 19 of Set 10 | Kopyevo
# The requested city of: Kopyevo was not found. Skipping...
# Processing Record 20 of Set 10 | College
# Processing Record 21 of Set 10 | Santa Maria
# Processing Record 22 of Set 10 | Zmeinogorsk
# Processing Record 23 of Set 10 | Inhambane
# Processing Record 24 of Set 10 | Payo
# Processing Record 25 of Set 10 | Kazerun
# Processing Record 26 of Set 10 | Bournemouth
# Processing Record 27 of Set 10 | Batetskiy
# Processing Record 28 of Set 10 | Haines Junction
# Processing Record 29 of Set 10 | Kholodnyy
# Processing Record 30 of Set 10 | Manadhoo
# Processing Record 31 of Set 10 | Port Blair
# Processing Record 32 of Set 10 | Bulgan
# Processing Record 33 of Set 10 | Beian
# Processing Record 34 of Set 10 | Lesnoy
# Processing Record 35 of Set 10 | San Pedro
# Processing Record 36 of Set 10 | Sisimiut
# Processing Record 37 of Set 10 | Mayo
# Processing Record 38 of Set 10 | Xining
# Processing Record 39 of Set 10 | Lillooet
# Processing Record 40 of Set 10 | Sorvag
# The requested city of: Sorvag was not found. Skipping...
# Processing Record 41 of Set 10 | Dothan
# Processing Record 42 of Set 10 | Draguignan
# Processing Record 43 of Set 10 | Ha Giang
# Processing Record 44 of Set 10 | Jiayuguan
# Processing Record 45 of Set 10 | Kovdor
# Processing Record 46 of Set 10 | Skibbereen
# Processing Record 47 of Set 10 | Vieques
# Processing Record 48 of Set 10 | Beresti-Tazlau
# Processing Record 49 of Set 10 | Nara
# Processing Record 50 of Set 10 | Holland
# Processing Record 1 of Set 11 | Iroquois Falls
# Processing Record 2 of Set 11 | Bonfim
# Processing Record 3 of Set 11 | Bouna
# Processing Record 4 of Set 11 | Acapulco
# Processing Record 5 of Set 11 | Ojinaga
# Processing Record 6 of Set 11 | Turukhansk
# Processing Record 7 of Set 11 | Richard Toll
# The requested city of: Richard Toll was not found. Skipping...
# Processing Record 8 of Set 11 | Mbeya
# Processing Record 9 of Set 11 | Beringovskiy
# Processing Record 10 of Set 11 | Luanda
# Processing Record 11 of Set 11 | Ekibastuz
# Processing Record 12 of Set 11 | Serenje
# Processing Record 13 of Set 11 | Ruteng
# Processing Record 14 of Set 11 | Taoudenni
# Processing Record 15 of Set 11 | Sajalices
# Processing Record 16 of Set 11 | Loreto
# Processing Record 17 of Set 11 | Sundsvall
# Processing Record 18 of Set 11 | Mitu
# Processing Record 19 of Set 11 | Novosokolniki
# Processing Record 20 of Set 11 | Fort Dodge
# Processing Record 21 of Set 11 | Port-Gentil
# Processing Record 22 of Set 11 | Martil
# Processing Record 23 of Set 11 | Bokspits
# The requested city of: Bokspits was not found. Skipping...
# Processing Record 24 of Set 11 | Minot
# Processing Record 25 of Set 11 | San Fernando
# Processing Record 26 of Set 11 | Hami
# Processing Record 27 of Set 11 | Jozefow
# Processing Record 28 of Set 11 | Tautira
# Processing Record 29 of Set 11 | Kualakapuas
# Processing Record 30 of Set 11 | Half Moon Bay
# Processing Record 31 of Set 11 | Sulangan
# Processing Record 32 of Set 11 | We
# The requested city of: We was not found. Skipping...
# Processing Record 33 of Set 11 | Brae
# Processing Record 34 of Set 11 | Kamenka
# Processing Record 35 of Set 11 | Tsiroanomandidy
# Processing Record 36 of Set 11 | Lorengau
# Processing Record 37 of Set 11 | Husavik
# Processing Record 38 of Set 11 | Baharampur
# Processing Record 39 of Set 11 | Normal

# %%
# accounting for skips!

print(skip_counter)
# print(skip_list)

# %%
#print(city_name)
print()
print(len(city_name))

# %%
# Status code errors - this is to see which cities and their
# respective status codes resulted in an error from the API call

# print(cod)
# print()
print(len(cod))

# %%
#checks
#print(cloudiness)

# %%
# checks
#print(country)

# %%
#checks
# print(date)
# print(len(date))

# %%
# checks
#print(humidity)

# %%
# checks
#print(lat)

# %%
# # checks
# print(lng)

# %%
# checks
#print(max_temp)

# %%
# checks
#print(wind_speed)

# %%
# VALUES ZIP BELOW WAS USED SUCCESSFULLY FOR CONVERTING THE LISTS TO A ZIP TO A CSV FILE (LOOKED IN PYTHON DAY 2 @ UDEMY ACTIVITY)
values_zip = zip(city_name, cloudiness, country, date, humidity, lat, lng, max_temp, wind_speed)

# %%
# CONVERT TO CSV FILE

with open('city_data_JG2.csv', 'w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng', 'Max Temp (Kelvin)', 'Wind Speed'])
    writer.writerows(values_zip)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydata_csvto_pd = pd.read_csv('city_data_JG2.csv')
print(citydata_csvto_pd.head())

# %%
df_city_data = pd.DataFrame(citydata_csvto_pd)
df_city_data.count()

# %%
df_city_data.head()

# this was ran a few times. I added the Max Temp Column (Fahrenheit) in the next section

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Convert Temperature from Kelvins to Fahrenheit and set it up as a variable
max_temp_slice_F = (df_city_data.loc[:, ['Max Temp (Kelvin)']] - 273.15) * (9/5) + 32

# Add new column into dataframe
df_city_data['Max Temp (Fahrenheit)'] = max_temp_slice_F

# set up the latitude variable
lat = df_city_data.loc[:, ['Lat']]

plt.figure(1)
plt.scatter(lat, max_temp_slice_F, marker='o', edgecolor='black', facecolors='lightsteelblue')

plt.title("City Latitude vs Max Temperature (08/22/2018)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.show()
plt.savefig('./citylatitude_vs_maxtemp.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
humidity_percent = df_city_data.loc[:, ['Humidity']]

plt.figure(2)
plt.scatter(lat, humidity_percent, marker='o', edgecolor='black', facecolors='lightsteelblue')

plt.title("City Latitude vs Humidity (08/22/2018)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()

plt.savefig('./citylatitude_vs_humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cloudiness_data = df_city_data.loc[:, ['Cloudiness']]

plt.figure(3)
plt.scatter(lat, cloudiness_data, marker='o', edgecolor='black', facecolors='lightsteelblue')

plt.title("City Latitude vs Cloudiness (08/22/2018)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.show()

plt.savefig('./citylatitude_vs_cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
windspeed_data = df_city_data.loc[:, ['Wind Speed']]

plt.figure(4)
plt.scatter(lat, windspeed_data, marker='o', edgecolor='black', facecolors='lightsteelblue')

plt.title("City Latitude vs Wind Speed (08/22/2018)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.show()

plt.savefig('./citylatitude_vs_windspeed.png')

# %% [markdown]
# # DATA ANALYSIS
#
# ### Note: most of the random sample populated more cities with latitudes between the 0 to 80 than -60 to 0.
#
# ####  The data from the respective charts suggest:
#
# *	In the City Latitudes vs Temperatures (F) Chart, I found that cities with latitudes of -60 to 20 had the highest temperatures. This makes sense because a latitude of zero is near Africa, which is known to be very hot and is near the equator.
# *	Overall, the City Latitudes vs Humidity chart illustrates that overall, latitudes did not impact humidity levels. However, there were more cities with latitudes between 0 to 80 had slightly more humidity than cities between -60 to 0.
# *	As for the City Latitude vs Cloudiness Chart, the scatterplot suggests that cities latitudes between 0 to 80 were slightly more likely to be cloudier than cities between -60 and 0.
# *	Lastly, in the City Latitude vs Wind Speed Chart, the data suggests that cities with latitudes between 0 to 80 experienced slightly higher windspeeds, but overall sample comparable.
